# %% [markdown]
# RAG Architecture Chatbot

# %%
from dotenv import load_dotenv

load_dotenv(dotenv_path=".env", override=True)
# Out:
# True

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# %%
from langchain_community.document_loaders import PyPDFDirectoryLoader

loader = PyPDFDirectoryLoader('./data/pdf')

docs = loader.load()

docs[0].page_content
# Out:
# 'HP  Notebook  PCs  -  Testing  and  calibrating  \nthe\n \nbattery\n \n(Windows)\n Calibrate  the  battery  manually  \nManually  calibrating  the  battery  requires  you  to  discharge  or  drain  the  battery,  and  then  \nto\n \nrecharge\n \nthe\n \nbattery.\n \nThese\n \ninstructions\n \nwork\n \nwith\n \nmost\n \nbattery\n \ntypes.\n \nRun  a  battery  test  after  calibrating  the  battery.  Calibrating  the  battery  improves  the  \naccuracy\n \nof\n \nthe\n \nbattery\n \ngauge\n \nsoftware\n \nso\n \nthat\n \nit\n \nmore\n \naccurately\n \ndisplays\n \nthe\n \ncurrent\n \nlevel\n \nof\n \ncharge.\n \nNote:  You  do  not  need  to  fully  charge  the  battery  before  you  calibrate  it.  Turn  on  the  \ncomputer\n \nand\n \nuse\n \nHP\n \nPC\n \nHardware\n \nDiagnostics\n \nUEFI\n \nto\n \ndischarge\n \nthe\n \nbattery.\n \nYou  do  need  to  update  HP  PC  Hardware  Diagnostics  UEFI  to  the  latest  version.  To  \ndownload\n \nthe\n \nlatest\n \nversion,\n \ngo\n \nto\n \nthe\n \nHP\n \nPC\n \nHardware\n \nDiagnostics\n \nwebsite.\n \nSelect\n \nDiagnose\n \nPC\n \nissues\n \noutside\n \nof\n \nthe\n \nOS,\n \nand\n \nthen\n \nclick\n \nDownload.\n \nDischarge  the  battery  \nDischarge  the  battery  using  HP  PC  Hardware  Diagnostics  UEFI.  \nNote:  If  the  computer  battery  is  already  drained  and  the  computer  cannot  turn  on  when  \nyou\n \nbegin\n \nthis\n \nprocedure,\n \nwait\n \na\n \nminimum\n \nof\n \n5.5\n \nhours\n \nand\n \nthen\n \ngo\n \nto\n \nRecharge\n \nthe\n \nbattery.\n \nDisconnect  the  AC  adapter.  \nPress  and  hold  the  power  button  for  at  least  five  seconds  to  turn  off  the  computer.  \nTurn  on  the  computer  and  immediately  press  esc  repeatedly,  about  once  every  second.  \nWhen  the  startup  menu  appears,  press  f2.  The  HP  PC  Hardware  Diagnostics  menu  is  \ndisplayed.\n \nClick  Component  Tests  in  the  main  menu.'

# %%
from langchain_text_splitters import RecursiveCharacterTextSplitter
import re
from langchain_core.documents import Document

def clean_text(text: str) -> str:
    # Replace multiple newlines/tabs with a single space
    text = re.sub(r"\s*\n\s*", " ", text)
    return text.strip()


cleaned_docs = [
    Document(
        page_content=clean_text(doc.page_content),
        metadata=doc.metadata
    )
    for doc in docs
]


text_splitter = RecursiveCharacterTextSplitter(

    chunk_size=200,
    chunk_overlap=50,
    add_start_index=True,
)
all_splits = text_splitter.split_documents(cleaned_docs)

print(f"Split blog post into {len(all_splits)} sub-documents.")
# Out:
# Split blog post into 469 sub-documents.

# %%
all_splits
# Out:
# [Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 0}, page_content='HP  Notebook  PCs  -  Testing  and  calibrating the battery (Windows) Calibrate  the  battery  manually Manually  calibrating  the  battery  requires  you  to  discharge  or  drain  the  battery,  and'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 151}, page_content='you  to  discharge  or  drain  the  battery,  and  then to recharge the battery. These instructions work with most battery types. Run  a  battery  test  after  calibrating  the  battery.  Calibrating'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 304}, page_content='after  calibrating  the  battery.  Calibrating  the  battery  improves  the accuracy of the battery gauge software so that it more accurately displays the current level of charge. Note:  You  do'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 455}, page_content='the current level of charge. Note:  You  do  not  need  to  fully  charge  the  battery  before  you  calibrate  it.  Turn  on  the computer and use HP PC Hardware Diagnostics UEFI to discharge the'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 604}, page_content='HP PC Hardware Diagnostics UEFI to discharge the battery. You  do  need  to  update  HP  PC  Hardware  Diagnostics  UEFI  to  the  latest  version.  To download the latest version, go to the HP PC'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 753}, page_content='To download the latest version, go to the HP PC Hardware Diagnostics website. Select Diagnose PC issues outside of the OS, and then click Download. Discharge  the  battery Discharge  the  battery'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 901}, page_content='Discharge  the  battery Discharge  the  battery  using  HP  PC  Hardware  Diagnostics  UEFI. Note:  If  the  computer  battery  is  already  drained  and  the  computer  cannot  turn  on  when you'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 1051}, page_content='and  the  computer  cannot  turn  on  when you begin this procedure, wait a minimum of 5.5 hours and then go to Recharge the battery. Disconnect  the  AC  adapter. Press  and  hold  the  power'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 1197}, page_content='the  AC  adapter. Press  and  hold  the  power  button  for  at  least  five  seconds  to  turn  off  the  computer. Turn  on  the  computer  and  immediately  press  esc  repeatedly,  about  once'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 1357}, page_content='press  esc  repeatedly,  about  once  every  second. When  the  startup  menu  appears,  press  f2.  The  HP  PC  Hardware  Diagnostics  menu  is displayed. Click  Component  Tests  in  the  main'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 1514}, page_content='Click  Component  Tests  in  the  main  menu.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 0}, page_content='Note:  The  purpose  is  to  drain  or  discharge  the  battery,  not  get  the  results  of  the  test. The battery discharges and the computer turns off before the test results are displayed. In'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 151}, page_content='off before the test results are displayed. In  the  list  of  Component  Tests,  click  Battery. On  the  Battery  Test  page,  click  Run  once.  The  Battery  Test  begins.  After  the  battery'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 298}, page_content='The  Battery  Test  begins.  After  the  battery passes the test, click Calibrate Battery. On  the  Battery  Calibration  page,  click  Start  Calibration. Note:  To  run  battery  calibration,  the'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 454}, page_content='Note:  To  run  battery  calibration,  the  HP  Battery  Health  Manager  setting  in  BIOS  must  be Let HP manage my battery charging. If your HP Battery Health Manager setting is different, click'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 610}, page_content='Health Manager setting is different, click Continue to change the setting when prompted. If  your  AC  adapter  is  still  connected,  disconnect  the  AC  adapter,  and  then  click  Continue to'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 757}, page_content='the  AC  adapter,  and  then  click  Continue to continue the process when prompted. HP  PC  Hardware  Diagnostics  UEFI  discharges  the  battery  and  displays  an  estimated time to completion.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 905}, page_content='and  displays  an  estimated time to completion. After the calibration process is complete, reconnect the AC adapter and turn on the computer at the times displayed on-screen. Note:  The'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 1047}, page_content='at the times displayed on-screen. Note:  The  recommended  times  to  reconnect  the  AC  adapter  and  turn  on  the  computer are usually about 6 and 10 hours after the calibration process is'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 1193}, page_content='6 and 10 hours after the calibration process is completed. Recharge  the  battery Recharge  the  battery  fully  to  finish  recalibrating  the  battery. Note:  If  you  run  HP  Battery  Check'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 1338}, page_content='battery. Note:  If  you  run  HP  Battery  Check  before  the  battery  charges  fully,  you  might  get  a  false battery failure result. Plug  in  the  AC  adapter  to  charge  the  battery. Charge'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 1492}, page_content='AC  adapter  to  charge  the  battery. Charge  the  battery  to  a  full  charge,  99%  to  100%.  This  takes  approximately  4  hours. Note:  If  you  are  using  a  business  notebook,  make'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 1, 'page_label': '2', 'start_index': 1640}, page_content='you  are  using  a  business  notebook,  make  sure  that  you  are  using  the  Let  HP manage my battery charging setting in HP Battery Health Manager. You must use this'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 0}, page_content='setting  to  fully  charge  the  notebook.  For  more  information,  go  to  HP  Business  Notebook PCs - HP Battery Health Manager. Note:  The  battery  continues  to  charge  whether  the  computer'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 154}, page_content='continues  to  charge  whether  the  computer  is  on  or  off. Check  the  battery  charge.  Turn  on  the  computer  and  start  Windows  normally.  Hover  the pointer over the battery icon in the'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 305}, page_content='Hover  the pointer over the battery icon in the system tray to view the battery charge percentage. Make sure that the battery charge percentage is 99% or 100%. Note:  If  you  plug  in  your  AC'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 452}, page_content='99% or 100%. Note:  If  you  plug  in  your  AC  adapter  and  immediately  run  the  HP  Battery  Check,  you might get a false failure showing that the battery is bad. If the battery is in a'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 597}, page_content='that the battery is bad. If the battery is in a low-charge state (that is, less than 3%), you might also get a false reading. Wait  two  hours  before  using  the  notebook. If  your  battery'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 741}, page_content='before  using  the  notebook. If  your  battery  failed,  continue  with  these  steps. If  your  battery  failed,  check  the  following  table  for  suggested  actions,  and  then  write down the'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 892}, page_content='suggested  actions,  and  then  write down the battery status and Failure ID. Keep the battery status and Failure ID so you have them available if you need to contact HP Customer Support. The'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 1036}, page_content='if you need to contact HP Customer Support. The information in the table is also available in the Test Logs section on the main menu. Status Message Suggested  action Passed The  battery  functions'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 2, 'page_label': '3', 'start_index': 1185}, page_content='Suggested  action Passed The  battery  functions  properly  and  as  expected. The  battery  does  not  need  calibration.  Read  the  remainder  of  the  message  for  more information. Calibrate'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 0}, page_content='The  battery  functions  correctly,  but  it  needs  to  be  calibrated. Read  and  respond  to  the  message  that  is  displayed.  If  the  option  to  use  the  HP  battery auto calibration feature'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 154}, page_content='use  the  HP  battery auto calibration feature is displayed, this is preferred. Otherwise, click Learn How to Calibrate your Battery for the steps to calibrate your battery. Note:  Battery'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 295}, page_content='steps to calibrate your battery. Note:  Battery  calibration  might  take  several  hours  to  complete  and  is  best  performed during long periods when the computer is not in use. Weak or Very'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 445}, page_content='when the computer is not in use. Weak or Very  Weak The  battery  functions  correctly,  but  due  to  normal  aging  of  the  battery,  the  battery  life between charges is now significantly'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 596}, page_content='life between charges is now significantly shorter than when it was new. This  status  message  is  displayed  when  there  is  decrease  in  capacity  of  battery  that occurs over time and with'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 747}, page_content='of  battery  that occurs over time and with use. The battery should be replaced to get the most working time out of your battery. Replace The  battery  reports  a  failure  and  needs  to  be'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 890}, page_content='battery  reports  a  failure  and  needs  to  be  replaced  as  soon  as  possible. Replace  the  battery.  If  your  computer  is  within  its  warranty  period,  you  can  contact  HP support to'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 1045}, page_content='period,  you  can  contact  HP support to verify if your battery is covered. To set up a repair online, go to HP Virtual Assistant. If this service is not available for your location, contact HP for'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 1196}, page_content='not available for your location, contact HP for further support. Failure  with  an  ID  number The  battery  experienced  a  hardware  failure. Write  down  the  battery  status  and  Failure  ID.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 1347}, page_content='down  the  battery  status  and  Failure  ID.  To  set  up  a  repair  online,  go  to  HP  Virtual Assistant. If this service is not available for your location, contact HP for further support. No'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 3, 'page_label': '4', 'start_index': 1500}, page_content='location, contact HP for further support. No  Battery'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'start_index': 0}, page_content='HP  Battery  Check  did  not  detect  a  battery. A  battery  is  not  installed  or  detected  in  the  battery  compartment.  If  a  battery  is  installed, remove the battery and inspect the pins'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'start_index': 159}, page_content='remove the battery and inspect the pins to see if there is dirt or other foreign matter blocking the connection. Fully insert a battery into the compartment if a battery was not inserted and you want'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'start_index': 316}, page_content='if a battery was not inserted and you want to test the battery in that compartment. Unknown HP  Battery  Check  could  not  access  the  battery. Remove  and  reinsert  the  battery.  You  might'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 4, 'page_label': '5', 'start_index': 462}, page_content='Remove  and  reinsert  the  battery.  You  might  need  to  download  and  install  all  the  updates from HP Support Assistant.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 0, 'page_label': '1', 'start_index': 0}, page_content='FLASH First  Learning  And  Support  Handbook  HARDWARE  MODULE *This  Document  must  be  used  only  as  a  Reference  material  during  your  Training  period . HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 1, 'page_label': '2', 'start_index': 0}, page_content='Who  are  We? HP  INC About  HP  CCCB  Customer  Care  Center  Bangalore    Divisions  in  CCCB   Personal  systems  (PS)/Personal  Computer  (PC)  I  work  for  PS  L1  Support  what  do  we'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 1, 'page_label': '2', 'start_index': 148}, page_content='I  work  for  PS  L1  Support  what  do  we  Support?   Desktop  and  Laptops/Notebooks   HP  INC  (Pcs  and  Printers)   REGIONS  that  we  support  from  CCCB  GA  =  Greater  Asia  =  Australia/'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 1, 'page_label': '2', 'start_index': 298}, page_content='from  CCCB  GA  =  Greater  Asia  =  Australia/  New  Zealand  =  (02:00  A.M)  SEA  =  Singapore/Malaysia  =  (05:30  A.M)  INDIA  =  (09:00  A.M)  EMEA  =  East  Middle  East  Asia  =  UK  ='),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 1, 'page_label': '2', 'start_index': 447}, page_content='EMEA  =  East  Middle  East  Asia  =  UK  =  (03:00  P.M)  US/Canada  =  (06:00  P.M)   PC  Business   Commercial  Offices/Organizations/Companies/Governments  etc.                   Consumer'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 1, 'page_label': '2', 'start_index': 607}, page_content='etc.                   Consumer   Personal  usage HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 0}, page_content='PS  INDIA  Teams   L0  Team  =  CDT  (Call  Director  Teams)  PS  Technical  L1  Voice  Support   SMB  =  Small  Medium  Business  support  NA  =  Named  Account  ADX  =  Account  Dynamics  Prime'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 147}, page_content='Named  Account  ADX  =  Account  Dynamics  Prime  Partner/CE  Assist   CT  =  Commodity  Tracking  team   POP  =  Proof  of  Purchase   DOA  =  Defective  on  Arrival  EMT  =  Escalation  Management'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 302}, page_content='on  Arrival  EMT  =  Escalation  Management  Team   CRT  =  Customer  Relationship  Team   Premium  =  Omen  by  HP,  Spectre,  HP  Slice,  ENVY   DSO  =  Desktop  Support  Organization  =  Thin'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 449}, page_content='DSO  =  Desktop  Support  Organization  =  Thin  clients,  Workstations,  RPOS  (Retail  Point  of  Sales)  Dispatch  /DVT  =  Dispatch  validation  Team   2LS  =2 nd Level  Support   3LS  =  3 rd'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 598}, page_content='Team   2LS  =2 nd Level  Support   3LS  =  3 rd Level  Support   Pro-Active  Management  Team  /DAAS  =  Device  as  a  Service    Support  Teams   Mentor/Trainers/Quality  analysts/RTAA  (Real'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 746}, page_content='Mentor/Trainers/Quality  analysts/RTAA  (Real  Time  Adherence  Analyst) Service  Level   sNPS  =  Support  Net  Promoter  Score   10  9  or  10  =  Promoter,8,7  =  Passive,  below  that  ='),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 2, 'page_label': '3', 'start_index': 888}, page_content='10  =  Promoter,8,7  =  Passive,  below  that  =  Detractor. HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 0}, page_content='sNPS  =  Support  Net  Promoter  Score   sNPS  =  Sales  Net  promoter  Score   sNPS  =  Service  Net  Promoter  Score    Service  level  Global  Coverage  This  PC  is  serviceable/Supportable'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 146}, page_content='Coverage  This  PC  is  serviceable/Supportable  across  the  world  Country  Coverage   This  PC  is  serviceable/Supportable  only  in  the  country  where  it  was  purchased.  Next  Avail  Tech'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 298}, page_content='where  it  was  purchased.  Next  Avail  Tech  Resource  Remote  When  Customer  reaches  Tech  support  whoever  is  available  in  the  tech  support  will  provide support to the customer. Next'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 451}, page_content='will  provide support to the customer. Next  Avail  Tech  Resource  Onsite  When  Customer  is  getting  an  Onsite  Tech  support  whoever  is  available  in  the  Onsite  support  will provide'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 596}, page_content='available  in  the  Onsite  support  will provide support to the customer Std  Office  Hrs  Std  Office  Days  No  Weekends  support  and  between  timings  are  standard  (In-General)  Standard'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 744}, page_content='timings  are  standard  (In-General)  Standard  Material  Handling  Regular  material  shipments  No  Usage  Limitation  Can  claim  warranty  under  terms  for  any  number  of  times  Next  Cov'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 894}, page_content='terms  for  any  number  of  times  Next  Cov  Day  Onsite  Response  One  business  day  on  Onsite  Response  is  available  Next  Coverage  Day  Service  Response  is  on  Next  day   Standard'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 1042}, page_content='Service  Response  is  on  Next  day   Standard  Parts  Logistics  Standard  Part  shipment  Accidental  Damage  Coverage  (ADP)  Coverage  of  Accidents/liquid  spill   How  is  your  Training'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 3, 'page_label': '4', 'start_index': 1204}, page_content='spill   How  is  your  Training  Plan  Designed? HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 0}, page_content='Hardware  Module  Evaluation   OS  Module  Evaluation   Network  Module  Evaluation   Final  Evaluations   70%  is  the  Passing  Score  in  all  the  Evaluations  and  in  Final  Evaluations.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 146}, page_content='the  Evaluations  and  in  Final  Evaluations.   Serial  Number   It  is  10  Digit  Unique  Alphanumeric  Number  to  identify  your  HP  PC/Monitor/Dock.  Different  ways  to  find  the  Serial'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 303}, page_content='Different  ways  to  find  the  Serial  Number  Serial  number,  product  number,  model  number,  warranty  details  etc.  S/N 1.  Base  enclosure  –  Bottom  enclosure  /Base  Enclosure  of  the'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 452}, page_content='–  Bottom  enclosure  /Base  Enclosure  of  the  Laptop  and   Top  enclosure  of  the  Desktop.  2.   BIOS  setup  utility.  3.  HP  Support  Assistant.  (HPSA)  4.  (laptops)  Fn  +  esc  =  this'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 607}, page_content='(HPSA)  4.  (laptops)  Fn  +  esc  =  this  will  Provide  the  serial  number,  Ctrl  +  Alt  +  S(Desktop) 5.  Command  prompt  =  wmic  bios  get  serialnumber .  6.  Bill  Copy  (only  for'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 4, 'page_label': '5', 'start_index': 752}, page_content='get  serialnumber .  6.  Bill  Copy  (only  for  INDIA  customers).     How  to  Decode  HP  PC  Serial  Number HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 0}, page_content='CND1051234  CND            1              05           1234   C=  China   I=  India   S  =  Singapore  M=  Malaysia  J=  Japan    CN  =  Country  of  Assembly  (C  =  China,  IN  =  India,  SG  ='),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 150}, page_content='Assembly  (C  =  China,  IN  =  India,  SG  =  Singapore,  IM=  Malaysia)  D  =  Site  Code   2021  2020  2019  2018  2017  2016  2015  2014  2013  2012   4  =  Year  of  Assembly/manufacture  The'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 298}, page_content='2012   4  =  Year  of  Assembly/manufacture  The  last  10  years  last  number.  05  =  Week   1234  =  Lot  code   OEM  =  Original  Equipment  manufacturers  for  Microsoft.    Manufacturers'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 444}, page_content='manufacturers  for  Microsoft.    Manufacturers  ->Distributors  ->  Resellers  (Can  be  more)  ->Customer  What  is  Obsolete  Unit  =  Product  manufacturing  stopped  =  1  year  EOSL  =  End'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 591}, page_content='manufacturing  stopped  =  1  year  EOSL  =  End  of  Support  Life  =  Products  Supports  life  stopped=  5  years    5CG7415FWT  INA618R2QR  8CG8513C2N  CND5305JFM HARDWARE  MODULE  REFERENCE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 5, 'page_label': '6', 'start_index': 747}, page_content='CND5305JFM HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 6, 'page_label': '7', 'start_index': 0}, page_content='SGH237SLL4    Product  Number  /  SKU  number  =  Stock  Keeping  unit    6  to  8  alphanumeric   Y3R94UC R# ABA  Country  of  the  pc  designed  for  =  USA  #ACJ  =  INDIA    R  before  the  #  tag'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 6, 'page_label': '7', 'start_index': 152}, page_content='=  USA  #ACJ  =  INDIA    R  before  the  #  tag  refers  to  the  PC  is  a  Refurbished  PC    HP  refurbished  Warranty  =  90  Days     1y  1 y  1y   3y  3y  1y  3y  3y  0y   1Y  1Y  1Y  Support'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 6, 'page_label': '7', 'start_index': 301}, page_content='1y   3y  3y  1y  3y  3y  0y   1Y  1Y  1Y  Support / parts / On-site   Care-paq  Contract  OOW  =  Out  of  warranty   INW  =  In  warranty   Base  Warranty  /  Manufacturer  Warranty    No  Power,'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 6, 'page_label': '7', 'start_index': 458}, page_content='/  Manufacturer  Warranty    No  Power,  No  Display,  No  Boot,  No  Post    Beeps  and  Blink  Codes    Red  =  Major,  White=  Minor   2  =  BIOS  3  =  Any  HW  component  apart  from  system'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 6, 'page_label': '7', 'start_index': 608}, page_content='3  =  Any  HW  component  apart  from  system  board  3.2  =  Memory  3.3  =  Graphics  3.4  =  Power  3.5  =  Processor    4  =  Thermal/Fan  issue HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 7, 'page_label': '8', 'start_index': 0}, page_content='5  =  System-board  issue           Power  SMPS  =  Switch  Mode  Power  Supply   PSU  =  Power  Supply  Unit AC  Adapter HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 8, 'page_label': '9', 'start_index': 0}, page_content='Types  of  HP  AC  Adapters  available  for Notebooks and All-in-One PC’s Newer  Blue  Pin  Smart  Adapters  (4.5mm  barrel) Black  Pin  Smart  Adapters  (7.4mm  barrel) HP  USB-C  Power  Adapter'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 8, 'page_label': '9', 'start_index': 154}, page_content='(7.4mm  barrel) HP  USB-C  Power  Adapter HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 9, 'page_label': '10', 'start_index': 0}, page_content='HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 10, 'page_label': '11', 'start_index': 0}, page_content='Electromagnetic  compatibility,  or EMC  means that  a  device  is  compatible  with  (no  interference  is caused by) its electromagnetic (EM) environment and it does not emit levels of EM energy'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 10, 'page_label': '11', 'start_index': 156}, page_content='and it does not emit levels of EM energy that cause electromagnetic interference (EMI) in other devices in the vicinity. PFC  Power  Factor  Correction HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 11, 'page_label': '12', 'start_index': 0}, page_content='HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 12, 'page_label': '13', 'start_index': 0}, page_content='BATTERY  IS  A  CONSUMABLE  PART  Without  a  Valid  Failure  id  battery  will  not  be  replaced.  Differentiate  the  Battery  Lithium-ion  XL  Battery  (Xtra  Life)  Warranty:  3  years  Cycle'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 12, 'page_label': '13', 'start_index': 156}, page_content='(Xtra  Life)  Warranty:  3  years  Cycle  count:  1000  Cycles   Lithium-ion  CL  Battery  (Normal  Battery)  Warranty:  1  year   Cycle  Count:   300  cycles    Design  Capacity:  53  WHr  Full'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 12, 'page_label': '13', 'start_index': 303}, page_content='300  cycles    Design  Capacity:  53  WHr  Full  Charge  Capacity:  49  WHr HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 13, 'page_label': '14', 'start_index': 0}, page_content='Cycle  Count   One  Full  Charge  and  One  Full  Discharge  of  a  battery  is  called  as  One  Cycle.   Battery  calibration:   Charge  and  discharge  the  PC  for  3  times   3rd  party  products'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 13, 'page_label': '14', 'start_index': 155}, page_content='the  PC  for  3  times   3rd  party  products  being  used   Environmental  dispose  reasons    Battery  Bulging    Battery  Test:  HP  Support  Assistant   HP  UEFI  Diagnostics   HP  Hardware'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 13, 'page_label': '14', 'start_index': 300}, page_content='Assistant   HP  UEFI  Diagnostics   HP  Hardware  Diagnostics  for  windows     LAPTOP   NOTEBOOK  Lightweight  Analytical  Platform  Total  Optimized  Power  ACPI  power  states   Advanced'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 13, 'page_label': '14', 'start_index': 441}, page_content='Optimized  Power  ACPI  power  states   Advanced  configuration  power  interface  S0  =  System  is  fully  functioning  (usable)  S0  LPI  (Low  power  Idle)  =  Modern  standby  (Sleep)  =  SOC  ='),
# ...
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 83, 'page_label': '84', 'start_index': 138}, page_content='5.  How  to  do  Power  Reset/Power  Drain   https://support.hp.com/vn-en/product/hp-15-notebook-pc-series/10862300/document/c01684768  6.  CBR  without  Flash  Drive'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 83, 'page_label': '84', 'start_index': 274}, page_content='6.  CBR  without  Flash  Drive   https://www.youtube.com/watch?v=qpiGUojtr3E   7.  CBR  using  Flash  Drive   https://www.youtube.com/watch?v=zjAZ0DTX3aI  8.  CBR  /  CMOS  Reset'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 83, 'page_label': '84', 'start_index': 429}, page_content='8.  CBR  /  CMOS  Reset   https://support.hp.com/hr-en/document/c02693833  9.  Desktop  PC  Beep  or  blink  Codes:   https://support.hp.com/us-en/document/ish_1997210-1528385-16   10.  Notebook  PC'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 83, 'page_label': '84', 'start_index': 610}, page_content='10.  Notebook  PC  Beep  and  Blink  Codes:  https://support.hp.com/us-en/document/ish_1997719-1528356-16   11.  PC  starts  with  Blank  screen:  https://support.hp.com/in-en/document/c03518165'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 83, 'page_label': '84', 'start_index': 757}, page_content='https://support.hp.com/in-en/document/c03518165 HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 0}, page_content='12.  Notebook  and  AIO  Display  issues:   https://support.hp.com/in-en/document/c01881110 https://support.hp.com/in-en/document/c01608578  13.  PC  is  slow:'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 141}, page_content='13.  PC  is  slow:  https://support.hp.com/us-en/document/c06102177  14.  PC  Fan  is  Noisy:  https://support.hp.com/in-en/document/c01007591  15.  Understanding  Battery  Warranties:'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 285}, page_content='15.  Understanding  Battery  Warranties:   https://support.hp.com/in-en/document/c05843717  16.  Bit  locker:  https://support.hp.com/in-en/document/c06432394  17.  UEFI  Diagnostics'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 445}, page_content='17.  UEFI  Diagnostics https://support.hp.com/us-en/document/ish_2854458-2733239-16    18.  BIOS  Simulators    Consumers:    http://h10032.www1.hp.com/ctg/Manual/c06527752'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 571}, page_content='http://h10032.www1.hp.com/ctg/Manual/c06527752 http://h10032.www1.hp.com/ctg/Manual/c06498459 ●  No  PDPB  ●  Three  R’s As  per  HP  Warranty  Terms  and  Conditions  HP  has  defined  LCD'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 715}, page_content='Terms  and  Conditions  HP  has  defined  LCD  screen  related  issues  in  this  document   The  document  is   h t t p s : / / s u p p o r t . h p . c o m / i n - e n / d o c u m e n t / c 0 1 8 8'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 864}, page_content='. c o m / i n - e n / d o c u m e n t / c 0 1 8 8 1 1 1 0  h t t p s : / / s u p p o r t . h p . c o m / i n - e n / d o c u m e n t / c 0 1 6 0 8 5 7 8  As  per  that  document  the  issue  is  not'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 84, 'page_label': '85', 'start_index': 1015}, page_content='8  As  per  that  document  the  issue  is  not  covered  under  HP  Warranty  terms  and  conditions  for  your  PC HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 0}, page_content='Power 1.  Desktop  PC  is  not  powering  on  –  TBS   2.  Notebook  PC/AIO/Mini  Desktop  PC  is  Not  powering  ON   3.  How  to  do  Second  Level  Power  Drain  or  Bare  Minimum  in  Desktop  PC'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 151}, page_content='Power  Drain  or  Bare  Minimum  in  Desktop  PC   4.  Battery  is  giving  less  backup  only  how-to  tbs.   5.  Battery  is  Bulging  how  to  tbs.  6.  Plugged  in  not  charging  how  to  tbs'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 303}, page_content='6.  Plugged  in  not  charging  how  to  tbs   7.  Battery  is  charging  only  till  80%  how  to  tbs   =  Battery  Health  manager.    h t t p s : / / s u p p o r t . h p . c o m / i n - e n / d'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 451}, page_content=': / / s u p p o r t . h p . c o m / i n - e n / d o c u m e n t / c 0 6 4 6 5 9 5 9  8.  AC  adapter  is  overheating  tbs?  9.  SMART  Ac  adapter  Error  message  tbs?   10.  PC  is  restarting'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 600}, page_content='Error  message  tbs?   10.  PC  is  restarting  continuously  after/before  Showing  HP  Logo  (No  POST).  11.  PC  is  Overheating  –  PULSE  –  PSIR  -  Thermal  Event. Blink  Codes 12.'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 744}, page_content='–  PSIR  -  Thermal  Event. Blink  Codes 12.  Notebook/Desktop  PC  is  Blinking  2/3/4/5  Major  Blinks  or  Beeps. Display 13.  No  Display  in  Desktop  PC    14.  No  Display  in  AIO  Desktop'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 900}, page_content='PC    14.  No  Display  in  AIO  Desktop  PC   15.  No  Display  in  Notebook  PC   16.  Display  is  Having  vertical/  Horizontal  Lines/  Half  screen  how  to  proceed  in  Desktop  or  Notebook'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 1055}, page_content='how  to  proceed  in  Desktop  or  Notebook  PC?  17.  Display  is  Blurred/  Blinking  –  Troubleshoot  –  Desktop  PC/Notebook  PC?  18.  Display  has  no  Backlight–  Troubleshoot  –  Desktop  or'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 1204}, page_content='has  no  Backlight–  Troubleshoot  –  Desktop  or  Notebook  pc?  19.  Display  is  having  Dead  Pixels  for  a  monitor/Notebook  how  to  Proceed? POST 20.  3F0/301/  Short  DST  Warning  Error/'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 85, 'page_label': '86', 'start_index': 1354}, page_content='POST 20.  3F0/301/  Short  DST  Warning  Error/  SMART  Imminent  Failure  Troubleshoot.     21.  601  Error  Troubleshoot   22.  90B  Error  Troubleshoot HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 86, 'page_label': '87', 'start_index': 0}, page_content='---------------------------------------------------- THE  END ------------------------------------------ HARDWARE  MODULE  REFERENCE  GUIDE'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 0}, page_content='How  to  Fix  an  HP  Laptop  That  Won’t  Turn  On Power  Button  Hard  Reset  -  30  seconds The  easiest  and  most  effective  solution  is  performing  a  hard  reset.  Turn  off  your  HP laptop'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 157}, page_content='a  hard  reset.  Turn  off  your  HP laptop completely, disconnect the AC adapter, and remove the battery if possible. Press and hold the power button for 15 seconds to discharge any residual'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 301}, page_content='button for 15 seconds to discharge any residual electrical charge. This clears temporary configurations that may prevent your laptop from starting. Reconnect the power adapter (and battery if you'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 449}, page_content='Reconnect the power adapter (and battery if you removed it) and try turning on your laptop. Check  Power  Connections  -  1  minute  Verify  that  your  AC  adapter  is  properly  connected  to  both'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 602}, page_content='AC  adapter  is  properly  connected  to  both  the  laptop  and  wall  outlet.  The connection should be secure at both ends, with no wobbling or looseness. Check if the LED indicator on your power'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 760}, page_content='Check if the LED indicator on your power adapter brick is lit - this confirms power is flowing from the outlet. If your laptop has a charging LED near the power port, it should glow white, amber, or'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 911}, page_content='the power port, it should glow white, amber, or green when properly connected. Try a different wall outlet if the adapter LED isn’t lighting up. Battery  Quick  Test  -  2  minutes If  your  HP'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 1056}, page_content='Battery  Quick  Test  -  2  minutes If  your  HP  laptop  has  a  removable  battery,  take  it  out  and  inspect  the  metal  contact points for any corrosion or damage. Clean them gently with a'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 1203}, page_content='any corrosion or damage. Clean them gently with a dry cloth if needed. Try powering the laptop with just the AC adapter connected and no battery installed. If it turns on, your battery may need'),
#  Document(metadata={'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 1348}, page_content='installed. If it turns on, your battery may need replacement. For laptops with non-removable batteries, connect the AC adapter and let it charge for at least 15 minutes before attempting to power on.')]

# %%
from langchain_huggingface import HuggingFaceEmbeddings

embeddings = HuggingFaceEmbeddings(model_name="sentence-transformers/all-mpnet-base-v2")

# %%
from langchain_core.vectorstores import InMemoryVectorStore

vector_store = InMemoryVectorStore(embeddings)

# %%
document_ids = vector_store.add_documents(documents=all_splits)

print(document_ids[:3])
# Out:
# ['3c5e2352-f6d2-4f12-bb4d-510a9fe01327', '309de1e0-70bd-4992-8cea-e3a6e98ed4a6', 'b9bd3d1c-2326-4aad-91b5-8d992536b901']

# %%
retriever = vector_store.as_retriever(
    search_type="similarity",
    search_kwargs={"k": 3},
)

# %%
from langchain_ollama.chat_models import ChatOllama

model = ChatOllama(
    model="llama3.2:latest",
    temperature=0.5,
    streaming=True
)

# %%
from langchain.tools import tool

@tool(response_format="content_and_artifact")
def retrieve_context(query: str):
    """Retrieve information to help answer a query."""
    retrieved_docs = vector_store.similarity_search(query, k=4)
    serialized = "\n\n".join(
        (f"Source: {doc.metadata}\nContent: {doc.page_content}")
        for doc in retrieved_docs
    )
    return serialized, retrieved_docs

# %%
from langchain.agents import create_agent
from langsmith import traceable

tools = [retrieve_context]
# If desired, specify custom instructions
prompt = (
    "You are a customer support agent for a laptop manufacturing company and you specialize in providing personalized answers."
    "Use the tool to help answer user queries."
)


@traceable
def run_agent(query: str):
    agent = create_agent(model, tools, system_prompt=prompt)

    for event in agent.stream(
        {"messages": [{"role": "user", "content": query}]},
        stream_mode="values",
    ):
        event["messages"][-1].pretty_print()

# %%
query = (
    "How to fix no power issue?"
    "Once you get the answer, look up common extensions of that method."
)


run_agent(query)
# Out:
# ================================ Human Message =================================
#
# How to fix no power issue?Once you get the answer, look up common extensions of that method.
# ================================== Ai Message ==================================
# Tool Calls:
#   retrieve_context (9ae7a41f-af11-459e-b58d-d7fafb210149)
#  Call ID: 9ae7a41f-af11-459e-b58d-d7fafb210149
#   Args:
#     query: how to fix no power issue on laptop
# ================================= Tool Message =================================
# Name: retrieve_context
#
# Source: {'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 1203}
# Content: any corrosion or damage. Clean them gently with a dry cloth if needed. Try powering the laptop with just the AC adapter connected and no battery installed. If it turns on, your battery may need
#
# Source: {'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'HP Notebook PCs - Testing and calibrating the battery (Windows)', 'source': 'data\\pdf\\battery.pdf', 'total_pages': 5, 'page': 0, 'page_label': '1', 'start_index': 1051}
# Content: and  the  computer  cannot  turn  on  when you begin this procedure, wait a minimum of 5.5 hours and then go to Recharge the battery. Disconnect  the  AC  adapter. Press  and  hold  the  power
#
# Source: {'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'No power Issue', 'source': 'data\\pdf\\power.pdf', 'total_pages': 1, 'page': 0, 'page_label': '1', 'start_index': 449}
# Content: Reconnect the power adapter (and battery if you removed it) and try turning on your laptop. Check  Power  Connections  -  1  minute  Verify  that  your  AC  adapter  is  properly  connected  to  both
#
# Source: {'producer': 'Skia/PDF m145 Google Docs Renderer', 'creator': 'PyPDF', 'creationdate': '', 'title': 'Hardware Module Reference Guide .docx', 'source': 'data\\pdf\\HardwareGuide.pdf', 'total_pages': 87, 'page': 78, 'page_label': '79', 'start_index': 903}
# Content: happened  in  the PC? Try  to  Replicate  the  issue.   NO  POWER  IN  DESKTOP :  1.  When  =  3  days  before   2.  What  =  No  HW/SW  changes   3.  Damages  =  No   4.  The  Power  chord  is
# ================================== Ai Message ==================================
#
# **Fixing No Power Issue on Laptop**
#
# If your laptop is not turning on and you're experiencing a no power issue, here are some steps to try:
#
# 1. **Clean the power ports**: Corrosion or damage in the power ports can prevent your laptop from turning on. Clean them gently with a dry cloth if needed.
# 2. **Try powering with just the AC adapter**: Connect the AC adapter to the laptop and no battery installed. If it turns on, your battery may need calibration or replacement.
# 3. **Calibrate the battery**: If your laptop is not turning on when you begin this procedure, wait for at least 5.5 hours and then go to recharge the battery.
# 4. **Press and hold the power button**: Disconnect the AC adapter. Press and hold the power button for 30 seconds to discharge any residual power in the system.
# 5. **Reconnect the power adapter and try turning on**: Reconnect the power adapter (and battery if you removed it) and try turning on your laptop.
#
# **Additional Tips**
#
# * Make sure that your AC adapter is properly connected to both the laptop and the power source.
# * If you've recently installed any new hardware or software, try removing them to see if they're causing the issue.
# * If none of these steps work, it may be worth seeking further assistance from a professional repair service.
#
# Note: These steps are based on general troubleshooting methods and may not apply to all laptop models. If you're unsure about how to proceed, it's always best to consult your laptop's user manual or contact the manufacturer's support team for guidance.
